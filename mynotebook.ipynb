# %% [raw]
# import pandas as pd
# pd.plotting.register_matplotlib_converters()
# import matplotlib.pyplot as plt
# %matplotlib inline
# import seaborn as sns
# print("Setup Complete")

# %%
import pandas as pd
pd.plotting.register_matplotlib_converters()
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
print("Setup Complete")

# %%
filepath="../input/credit-card-approval-clean-data/clean_dataset.csv"
pd.read_csv(filepath)
